# %%
# Прочитайте файл 2017_jun_final.csv за допомогою методу read_csv
import pandas as pd
url = 'https://docs.google.com/spreadsheets/d/1bclX5PbqE8zR1-wOSM3ZTFa53sIC7RXqwty7Abmw9yQ'
path = r'C:\PythonProject\Python_Data_Science\2017_jun_final - 2017_jun_final.csv'
data = pd.read_csv(path)

# %%
# Прочитайте отриману таблицю, використовуючи метод head
data.head(5)
# Out:
#    N                    Посада Мова програмування Спеціалізація  \
# 0  1        Junior QA engineer                NaN     Manual QA
# 1  2        Junior QA engineer                NaN     Manual QA
# 2  3         Software Engineer            C#/.NET           NaN
# 3  4         Software Engineer         JavaScript           NaN
# 4  5  Senior Software Engineer         JavaScript           NaN
#
#   Загальний досвід роботи Досвід роботи на поточному місці  \
# 0                     0.5                              0.5
# 1         менше 3 місяців                  менше 3 місяців
# 2                       4                                1
# 3                       5                                4
# 4       10 і більше років                              0.5
#
#    Зарплата на місяць  Зміна зарплати за 12 місяців   Місто   Розмір компанії  \
# 0                 400                             0  Харків        до 10 осіб
# ...

# %%
# Визначте розмір таблиці за допомогою методу shape
data.shape
# Out:
# (8704, 25)

# %%
# Визначте типи всіх стовпців за допомогою dataframe.dtypes
data.dtypes
# Out:
# N                                     int64
# Посада                               object
# Мова програмування                   object
# Спеціалізація                        object
# Загальний досвід роботи              object
# Досвід роботи на поточному місці     object
# Зарплата на місяць                    int64
# Зміна зарплати за 12 місяців          int64
# Місто                                object
# Розмір компанії                      object
# Тип компанії                         object
# Стать                                object
# Вік                                   int64
# Освіта                               object
# Університет                          object
# Ще студент                             bool
# Рівень англійської                   object
# Предметна область                    object
# Дата заповнення                      object
# User.Agent                           object
# exp                                 float64
# ...

# %%
# Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)
data.isnull().sum()
# Out:
# N                                      0
# Посада                                 0
# Мова програмування                  3850
# Спеціалізація                       7219
# Загальний досвід роботи                0
# Досвід роботи на поточному місці       0
# Зарплата на місяць                     0
# Зміна зарплати за 12 місяців           0
# Місто                                  0
# Розмір компанії                        0
# Тип компанії                           0
# Стать                                  0
# Вік                                    0
# Освіта                                 0
# Університет                          358
# Ще студент                             0
# Рівень англійської                     0
# Предметна область                    223
# Дата заповнення                        0
# User.Agent                             0
# exp                                    0
# current_job_exp                        0
# salary                                 0
# ...

# %%
# Видаліть усі стовпці з пропусками, крім стовпця "Мова програмування"
new_data = data.drop(['Спеціалізація', 'Університет', 'Предметна область', 'Валюта', 'cls'], axis=1)

# %%
# Знову порахуйте, яка частка пропусків міститься в кожній колонці і переконайтеся, що залишився тільки стовпець "Мова.програмування"
new_data.isnull().sum(), new_data.shape
# Out:
# (N                                      0
#  Посада                                 0
#  Мова програмування                  3850
#  Загальний досвід роботи                0
#  Досвід роботи на поточному місці       0
#  Зарплата на місяць                     0
#  Зміна зарплати за 12 місяців           0
#  Місто                                  0
#  Розмір компанії                        0
#  Тип компанії                           0
#  Стать                                  0
#  Вік                                    0
#  Освіта                                 0
#  Ще студент                             0
#  Рівень англійської                     0
#  Дата заповнення                        0
#  User.Agent                             0
#  exp                                    0
#  current_job_exp                        0
#  salary                                 0
#  dtype: int64,
#  (8704, 20))

# %%
# Видаліть усі рядки у вихідній таблиці за допомогою методу dropna
clean_row_data = data.dropna()

# %%
# Визначте новий розмір таблиці за допомогою методу shape
clean_row_data.shape
# Out:
# (0, 25)

# %%
# Створіть нову таблицю python_data, в якій будуть тільки рядки зі спеціалістами, які вказали мову програмування Python
python_data = data[data['Мова програмування'] == 'Python']
python_data[:5]
# Out:
#        N                    Посада Мова програмування Спеціалізація  \
# 12    13         Software Engineer             Python           NaN
# 68    69         Software Engineer             Python           NaN
# 87    88  Junior Software Engineer             Python           NaN
# 114  115  Junior Software Engineer             Python           NaN
# 143  144  Junior Software Engineer             Python           NaN
#
#     Загальний досвід роботи Досвід роботи на поточному місці  \
# 12                        1                  менше 3 місяців
# 68                      1.5                              0.5
# 87                      0.5                              0.5
# 114                     1.5                              0.5
# 143                       1                                1
#
#      Зарплата на місяць  Зміна зарплати за 12 місяців Місто Розмір компанії  \
# 12                  800                           200  Київ      до 50 осіб
# ...

# %%
# Визначте розмір таблиці python_data за допомогою методу shape
python_data.shape
# Out:
# (207, 25)

# %%
# Використовуючи метод groupby, виконайте групування за стовпчиком "Посада"
python_data.groupby('Посада')

# %%
# Створіть новий DataFrame, де для згрупованих даних за стовпчиком "Посада", виконайте агрегацію даних за допомогою методу agg
# і знайдіть мінімальне та максимальне значення у стовпчику "Зарплата.в.місяць"
grouped = python_data.groupby(["Посада"])
grouped_salary=grouped["Зарплата на місяць"]
grouped_salary.agg(['max', 'min'])
# Out:
#                            max   min
# Посада
# Junior Software Engineer  1250   100
# Senior Software Engineer  9200  1300
# Software Engineer         5400   500
# System Architect          5000  3000
# Technical Lead            6200  1425

# %%
salarysalary = grouped_salary.agg(['max', 'min'])
salary
# Out:
#                            max   min
# Посада
# Junior Software Engineer  1250   100
# Senior Software Engineer  9200  1300
# Software Engineer         5400   500
# System Architect          5000  3000
# Technical Lead            6200  1425

# %%
# Створіть функцію fill_avg_salary, яка повертатиме середнє значення заробітної плати на місяць.
# Використовуйте її для методу apply та створіть новий стовпчик "avg"
def fill_avg_salary(arr):
    return arr.mean()
grouped_salary.apply(fill_avg_salary)
salary['avg'] = grouped_salary.apply(fill_avg_salary)
salary
# Out:
#                            max   min          avg
# Посада
# Junior Software Engineer  1250   100   560.841270
# Senior Software Engineer  9200  1300  3387.096774
# Software Engineer         5400   500  1799.070000
# System Architect          5000  3000  4000.000000
# Technical Lead            6200  1425  3165.909091

# %%
# Створіть описову статистику за допомогою методу describe для нового стовпчика.
salary['avg'].describe()
# Out:
# count       5.000000
# mean     2582.583427
# std      1387.255829
# min       560.841270
# 25%      1799.070000
# 50%      3165.909091
# 75%      3387.096774
# max      4000.000000
# Name: avg, dtype: float64

# %%
# Збережіть отриману таблицю в CSV файл
salary.to_csv(r'C:\PythonProject\Python_Data_Science\python_salary.csv', index=False)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

grouped_lang = data.groupby(['Мова програмування'])['N'].count() 
labels = grouped_lang.index
grouped_lang = grouped_lang.sort_values()[::-1]
labels = grouped_lang.index
plt.bar(labels[:8] ,grouped_lang[:8],
        color=["b", "r", "y", "g"],
        hatch='X',
       edgecolor='white',
       log=True)

plt.xlabel("Мова програмування", fontsize="small", color="midnightblue",)
plt.ylabel("Кількість розробників", fontsize="small", color="black")
plt.title("Кiлькісний розподіл розробників", fontsize=15)
plt.xticks(fontsize=8, color='darkblue',rotation=-45)
plt.show()

# %%
import seaborn as sns

salary_change = data.groupby(['Мова програмування'])['Зміна зарплати за 12 місяців'].mean()
salary_change = salary_change.sort_values()[::-1]
data_s = salary_change[:8]
plt.figure(figsize=(10,5))
plt.xticks(rotation=90, fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
sns.barplot(x="Мова програмування", y="Зарплата на місяць", data=data)
# Out:
# <Axes: xlabel='Мова програмування', ylabel='Зарплата на місяць'>

# %%
labels = ["Junior Software Engineer",
         "Senior Software Engineer",
         "Software Engineer",
         "System Architect",
         "Technical Lead"]
grouped_c = python_data.groupby(["Посада"]).count()
data_c = grouped_c['N']
explode = [0.15, 0, 0, 0, 0]
mycolors = ["yellow", "hotpink", "b", "#4CAF50", "red"]
plt.pie(
    data_c,
    labels=labels,
    shadow=True,
    explode=explode,
    autopct="%.2f%%",
    pctdistance=1.15,
    labeldistance=1.35,
    startangle=15,
    colors=mycolors)
plt.legend()
plt.title('кількісний розподіл', fontsize=15, loc='left')

plt.show()

# %%
# для побудови порівняльних лінийних графиків зарплатні ві рівня посади створимо датафрейми ще по двом мовам програмування
javaScript_data = data[data['Мова програмування'] == 'JavaScript']
java_data = data[data['Мова програмування'] == 'Java']
grouped_javaScript = javaScript_data.groupby(["Посада"])
grouped_java = java_data.groupby(["Посада"])

javaScript_salary = grouped_javaScript["Зарплата на місяць"].agg(['max', 'min'])
java_salary = grouped_java["Зарплата на місяць"].agg(['max', 'min'])
javaScript_salary, java_salary
# Out:
# (                           max   min
#  Посада
#  HTML coder                 600   385
#  Junior Software Engineer  2600    95
#  Senior Software Engineer  8000  1500
#  Software Engineer         5000   150
#  System Architect          5500  3500
#  Technical Lead            5500   800,
#                                  max   min
#  Посада
#  Data Scientist / Data Analyst  2700  2700
#  Junior Software Engineer       2000    75
#  Senior Software Engineer       8800   350
#  Software Engineer              7000   100
#  System Architect               7000  3000
#  Technical Lead                 6000  1600)

# %%
# відкинемо унікальні посади
javaScript_salary = javaScript_salary[1:]
java_salary = java_salary[1:]
javaScript_salary, java_salary
# Out:
# (                           max   min
#  Посада
#  Junior Software Engineer  2600    95
#  Senior Software Engineer  8000  1500
#  Software Engineer         5000   150
#  System Architect          5500  3500
#  Technical Lead            5500   800,
#                             max   min
#  Посада
#  Junior Software Engineer  2000    75
#  Senior Software Engineer  8800   350
#  Software Engineer         7000   100
#  System Architect          7000  3000
#  Technical Lead            6000  1600)

# %%
fig, axs = plt.subplots(figsize=(15,8))

axs.plot(salary.index, salary['max'],
         label='Python developer',
         color='purple',
         linewidth=2,
         marker="X")
axs.plot(javaScript_salary.index, javaScript_salary['max'],
         label='JavaScript developer',
         linestyle='--',
         color='red',
         linewidth=3,
         marker="D")
axs.plot(java_salary.index, java_salary['max'],
         label='Java developer',
         linestyle=':',
         color='blue',
         linewidth=3,
         marker="^")
plt.grid()
plt.xlabel('Посади',fontsize='large',fontstyle='oblique',fontweight='book',color='blue')
plt.ylabel('Рівень зарпалти',fontsize=12,fontstyle='italic',fontweight='book',color='green')
#plt.figure(figsize=(20,10))
plt.xticks(fontsize=10, color='blue',rotation=-15)
plt.legend()
plt.title('Зарпалта девелоперів', fontsize=15)

plt.show()
